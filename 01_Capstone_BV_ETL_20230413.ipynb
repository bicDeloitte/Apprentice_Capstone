# %% [markdown]
# ## Bic Vu's Capstone Project
# #### ML Guild - Apprentice Cohort 11
# #### Notebook 1
# 2023-04-13

# %%
import pandas as pd
import pandas_profiling as pf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.set_option("display.precision", 12) # Expand number char shown to 12 instead of scientific notation

from datetime import date
today = date.today()

# %%
# Create calculate_feature_statistics for quick feature overview
from pandas.api.types import is_numeric_dtype

def calculate_feature_statistics(data_frame):
    results = pd.DataFrame()
    for column in data_frame.columns:
        column_data = data_frame[column]
        if not is_numeric_dtype(column_data): continue
        num_zeros = (column_data == 0).sum()
        prop_zeros = num_zeros / len(column_data)
        num_positives = (column_data > 0).sum()
        prop_positives = num_positives / len(column_data)
        num_negatives = (column_data < 0).sum()
        prop_negatives = num_negatives / len(column_data)
        num_missing = column_data.isnull().sum()
        prop_missing = num_missing / len(column_data)
        #most_frequent_value = column_data.mode()[0]
        nunique_value = column_data.nunique()
        prop_nunique = nunique_value / len(column_data)
        min_value = column_data.min()
        max_value = column_data.max()
        median_value = column_data.median()
        feature_stats = pd.Series([num_zeros, prop_zeros, num_positives, prop_positives,
                                   num_negatives, prop_negatives, num_missing, prop_missing,
                                   #most_frequent_value, 
                                   nunique_value, prop_nunique, min_value, max_value, median_value],
                                  index=['num_zeros', 'prop_zeros', 'num_positives', 'prop_positives',
                                         'num_negatives', 'prop_negatives', 'num_missing', 'prop_missing',
                                         #'most_frequent_value', 
                                         'nunique_value', 'prop_nunique', 'min_value', 'max_value', 'median_value'])
        results[column] = feature_stats
    return results.T

# %%
# Create shortcut functions to display max rows and columns
def maxcol():
    pd.set_option('display.max_columns', None)
    return

def maxcol_reset():
    pd.reset_option('display.max_columns', None)
    return

def maxrow():
    pd.set_option('display.max_rows', None)
    return

def maxrow_reset():
    pd.reset_option('display.max_rows', None)
    return

# %% [markdown]
# ### Opt 1: Import raw data

# %%
# Get column names
filepath = "data/2021_lar.txt"
samp = pd.read_csv(filepath, sep="|", nrows=100)
print(samp.columns)

# %%
#### Read in selected columns of data
filepath = "data/2021_lar.txt"
cols = ['census_tract', 'derived_race', 'action_taken', 'loan_amount', 'property_value', 'income', 'debt_to_income_ratio', 'tract_minority_population_percent', 'tract_to_msa_income_percentage']

hmda = pd.read_csv(filepath, sep="|", usecols=cols)

# %%
print(hmda.shape)
hmda.head()

# %%
hmda.dtypes

# %%
# Export to save file
from datetime import date
today = date.today()

# Parquet can't convert multiple format columns?
# hmda.to_parquet("data/output/hmda_2021_sel_"+str(today), index=None)

hmda.to_csv("data/output/hmda_2021_sel_"+str(today)+".csv", index=None)

# %% [markdown]
# #### Filter out unused data

# %%
# Check for unsual properties in object columns. This has already been done on previous runs.

# maxrow()
# hmda.action_taken.value_counts()
# hmda.census_tract.value_counts()
# hmda.property_value.value_counts()
# hmda.derived_race.value_counts()

# %%
# Filter for action_taken
## 1 - Loan originated -- "Approved" KEEP
# 2 - Application approved but not accepted
## 3 - Application denied -- "Denied" KEEP
# 4 - Application withdrawn by applicant
# 5 - File closed for incompleteness
# 6 - Purchased loan
# 7 - Preapproval request denied
# 8 - Preapproval request approved but not accepted
# Select application action

hmda = hmda.loc[(hmda["action_taken"]==1) | (hmda["action_taken"]==3)]
hmda.shape

# %%
# Convert action_taken code
# Keep 1 as 1 for accepted values
# Convert 3 to 0 for rejected values

print(hmda["action_taken"].value_counts())
hmda["action_taken"] = hmda["action_taken"].apply(lambda x: x % 3)
hmda["action_taken"].value_counts()

# %%
# Drop values not used on race
print(hmda.shape)
hmda = hmda.loc[~((hmda["derived_race"]=="Race Not Available") | (hmda["derived_race"]=="Free Form Text Only"))]
# df = df.loc[~((df['team'] == 'A') | (df['assists'] > 6))]
print(hmda.shape)

# %%
# Drop property_value that are "Exempt", leaving only numberic value
print(len(hmda))
hmda = hmda[hmda.property_value != "Exempt"]
print(len(hmda))

# %%
hmda = hmda.dropna(how="any").reset_index(drop=True)

# %%
# Export to save file

# Parquet can't convert multiple format columns?
# hmda.to_parquet("data/output/hmda_2021_sel_"+str(today), index=None)

hmda.to_csv("data/output/hmda_2021_sel_"+str(today)+".csv", index=None)

# %% [markdown]
# ### Opt 2: Import saved sample data

# %%
# Skip Opt 1 and import selected data rows
hmda = pd.read_csv("data/output/hmda_2021_sel_2023-04-14.csv")
print(hmda.shape)
hmda.head()
# Out:
# /var/folders/2x/fv33h81566l4630885xd8kn40000gp/T/ipykernel_14419/564161503.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   hmda = pd.read_csv("data/output/hmda_2021_sel_2023-04-14.csv")
# (14512260, 9)
#     census_tract derived_race  action_taken  loan_amount  property_value  \
# 0   8059012022.0        White             1       335000        545000.0
# 1  51640070101.0        White             1       115000        185000.0
# 2  16027021001.0        White             1       115000        215000.0
# 3   6073008348.0        White             1       455000        715000.0
# 4   6013317000.0        White             1       325000        565000.0
#
#    income debt_to_income_ratio  tract_minority_population_percent  \
# 0    15.0                  NaN                              11.78
# 1    36.0                  NaN                              24.07
# 2    21.0                  NaN                              39.60
# 3    20.0                  NaN                              71.40
# 4    36.0                  NaN                              29.35
#
#    tract_to_msa_income_percentage
# 0                           140.0
# 1                            66.0
# 2                            79.0
# 3                           130.0
# 4                            71.0

# %% [markdown]
# #### Converting data types and formating geographic ids

# %%
hmda.dtypes
# Out:
# census_tract                          object
# derived_race                          object
# action_taken                           int64
# loan_amount                            int64
# property_value                       float64
# income                               float64
# debt_to_income_ratio                  object
# tract_minority_population_percent    float64
# tract_to_msa_income_percentage       float64
# dtype: object

# %%
hmda["property_value"] = pd.to_numeric(hmda["property_value"])
hmda.dtypes
# Out:
# census_tract                          object
# derived_race                          object
# action_taken                           int64
# loan_amount                            int64
# property_value                       float64
# income                               float64
# debt_to_income_ratio                  object
# tract_minority_population_percent    float64
# tract_to_msa_income_percentage       float64
# dtype: object

# %%
# Check how many census tracts are null. Will be using geography to combine with social capital data
nan = len(hmda[hmda["census_tract"]=="nA"])
nan
# Out:
# 1

# %%
# Some census tract values have decimals
hmda = hmda[hmda["census_tract"] != "nA"]
hmda["census_tract"] = pd.to_numeric(hmda["census_tract"])

# %%
# Check if any floats contains decimal before converting to ints
print((hmda["census_tract"] % 1  != 0).sum())
print((hmda["property_value"] % 1  != 0).sum())
print((hmda["income"] % 1  != 0).sum())
# Out:
# 83312
# 614758
# 882087

# %%
# Convert floats to ints
# May need to dropnas first
hmda = hmda.dropna(how="any").reset_index(drop=True)

# convert_dict = {"census_tract": "int",
#                 "property_value": "int",
#                 "income": "int"
#                 }
 
# hmda = hmda.astype(convert_dict, errors='ignore')

# hmda[["census_tract", "property_value", "income"]] = hmda[["census_tract", "property_value", "income"]].round(0).astype(int)

hmda = hmda.astype({
    "census_tract": "int",
    "property_value": "int",
    "income": "int"
})

hmda.dtypes
# Out:
# census_tract                           int64
# derived_race                          object
# action_taken                           int64
# loan_amount                            int64
# property_value                         int64
# income                                 int64
# debt_to_income_ratio                  object
# tract_minority_population_percent    float64
# tract_to_msa_income_percentage       float64
# dtype: object

# %%
# If census tract is a float, convert to an int then a string
hmda["census_tract"] = hmda["census_tract"].astype(str)
hmda.dtypes
# Out:
# census_tract                          object
# derived_race                          object
# action_taken                           int64
# loan_amount                            int64
# property_value                         int64
# income                                 int64
# debt_to_income_ratio                  object
# tract_minority_population_percent    float64
# tract_to_msa_income_percentage       float64
# dtype: object

# %%
# Create a column to count the length of census tract strings
hmda["ct_count"] = hmda["census_tract"].str.len()
hmda.tail()
# Out:
#          census_tract derived_race  action_taken  loan_amount  property_value  \
# 13051998  12099003509        White             1       755000         1005000
# 13051999  42091205200        White             1       995000         2255000
# 13052000   4013216816        White             1       905000         1575000
# 13052001   6037274202        White             1      2325000         2905000
# 13052002   6017031700        Asian             1       595000         1085000
#
#           income debt_to_income_ratio  tract_minority_population_percent  \
# 13051998    5801                 <20%                               4.74
# 13051999    6361                 <20%                              10.47
# 13052000    6711                 <20%                              14.79
# 13052001    9154                 <20%                              15.56
# 13052002     240             30%-<36%                              23.70
#
#           tract_to_msa_income_percentage  ct_count
# 13051998                           215.0        11
# 13051999                           178.0        11
# 13052000                           179.0        10
# 13052001                           273.0        10
# 13052002                           236.0        10

# %%
# check how many tracts have 11 char or other lengths
hmda.ct_count.value_counts()
# Out:
# 11    10253939
# 10     2798064
# Name: ct_count, dtype: int64

# %%
# Fill census_tract with leading 0 if less than 11 characters

hmda['census_tract'] = hmda['census_tract'].apply(lambda x: x.zfill(11))
hmda.tail()
# Out:
#          census_tract derived_race  action_taken  loan_amount  property_value  \
# 13051998  12099003509        White             1       755000         1005000
# 13051999  42091205200        White             1       995000         2255000
# 13052000  04013216816        White             1       905000         1575000
# 13052001  06037274202        White             1      2325000         2905000
# 13052002  06017031700        Asian             1       595000         1085000
#
#           income debt_to_income_ratio  tract_minority_population_percent  \
# 13051998    5801                 <20%                               4.74
# 13051999    6361                 <20%                              10.47
# 13052000    6711                 <20%                              14.79
# 13052001    9154                 <20%                              15.56
# 13052002     240             30%-<36%                              23.70
#
#           tract_to_msa_income_percentage  ct_count
# 13051998                           215.0        11
# 13051999                           178.0        11
# 13052000                           179.0        10
# 13052001                           273.0        10
# 13052002                           236.0        10

# %%
# Drop ct_count column used for data validation
hmda = hmda.drop(["ct_count"], axis=1)

# %% [markdown]
# #### Convert tract_to_msa_income_percentage to categorical data

# %%
# How the data source org CFPB uses tract to msa income to determine income level for lending
# https://www.consumerfinance.gov/data-research/consumer-credit-trends/mortgages/lending-neighborhood-income-level/

bins = [0,50, 80, 120, max(hmda["tract_to_msa_income_percentage"])]
bin_labels = ["low", "moderate", "middle", "upper"]

# %%
hmda["income_level"] = pd.cut(hmda["tract_to_msa_income_percentage"], bins, labels=bin_labels)
hmda["income_level"] = hmda["income_level"].astype(str)
hmda.head()
# Out:
#   census_tract derived_race  action_taken  loan_amount  property_value  \
# 0  06075030900        Joint             1       975000         1675000
# 1  06059052422        White             1      1125000         1925000
# 2  06111005600        White             1       675000         1055000
# 3  06061023800        White             1       335000          495000
# 4  06085503330        Asian             1      1285000         2175000
#
#    income debt_to_income_ratio  tract_minority_population_percent  \
# 0     123             20%-<30%                              54.88
# 1     179              50%-60%                              40.81
# 2     114                   45                              46.59
# 3      68                   38                               9.39
# 4     115              50%-60%                              89.83
#
#    tract_to_msa_income_percentage income_level
# 0                           146.0        upper
# 1                           159.0        upper
# 2                           110.0       middle
# 3                           101.0       middle
# 4                           174.0        upper

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.figure(figsize=[8, 6])
plt.xticks(rotation='vertical')

plt.hist(hmda["income_level"])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### ETL Debt to Income Ratio
# The DTI metric has a lot of categories with few values
# <p><a href = https://www.chase.com/personal/credit-cards/education/basics/what-is-debt-to-income-ratio-and-why-it-is-important#:~:text=Debt%2Dto%2Dincome%20ratio%20of,loan%20or%20line%20of%20credit.>Debt to Income categories</a>

# %%
hmda["debt_to_income_ratio"].value_counts()
# Out:
# 20%-<30%    2841057
# 30%-<36%    2282709
# <20%        1248579
# 50%-60%      659430
# 44           480573
# 42           474383
# >60%         462503
# 41           447894
# 40           441553
# 39           439254
# 43           437250
# 38           425028
# 37           417229
# 36           408893
# 49           355946
# 45           339497
# 46           299544
# 48           297116
# 47           292857
# Exempt          706
# 47.0              1
# 41.0              1
# Name: debt_to_income_ratio, dtype: int64

# %%
# Map new categories
mapping ={
    "<20%": "<20%",
    "20%-<30%": "20%-<30%",
    "30%-<36%": "30%-<36%",
    "36": "36%-<42%",
    "37": "36%-<42%",
    "38": "36%-<42%",
    "39": "36%-<42%",
    "40": "36%-<42%",
    "41": "36%-<42%",
    "42": "42%-<50%",
    "43": "42%-<50%",
    "44": "42%-<50%",
    "45": "42%-<50%",
    "46": "42%-<50%",
    "47": "42%-<50%",
    "48": "42%-<50%",
    "49": "42%-<50%",
    "50%-60%": "50%-60%",
    ">60%": ">60%"}

hmda["dti_level"] = hmda["debt_to_income_ratio"].map(mapping)
hmda["dti_level"] = hmda["dti_level"].astype(str)
hmda["dti_level"].value_counts()
# Out:
# 42%-<50%    2977166
# 20%-<30%    2841057
# 36%-<42%    2579851
# 30%-<36%    2282709
# <20%        1248579
# 50%-60%      659430
# >60%         462503
# nan             708
# Name: dti_level, dtype: int64

# %%
plt.figure(figsize=[8, 6])
plt.xticks(rotation='vertical')

# plt.hist(hmda["dti_level"]).loc(sort)

sort = ["<20%", "20%-<30%", "30%-<36%", "36%-<42%", "42%-<50%", "50%-60%", ">60%"]
hmda["dti_level"].value_counts().loc[sort].plot(kind='bar', legend=None)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(hmda.shape)
hmda.tail(60)
# Out:
# (13052003, 11)
#          census_tract derived_race  action_taken  loan_amount  property_value  \
# 13051943  06073003204        Joint             1      1035000         1305000
# 13051944  06037408705        Asian             1       685000          865000
# 13051945  06073005100        Asian             1       235000          315000
# 13051946  06073005600        Asian             1       215000          285000
# 13051947  06037534405        White             1       285000          505000
# 13051948  06037534405        White             1       565000          755000
# 13051949  06083000502        Joint             0      1785000         3085000
# 13051950  06037534405        White             1       285000          505000
# 13051951  06037700802        White             1      1855000         2715000
# 13051952  06059032058        White             1      2225000         2965000
# 13051953  06059062633        White             1      1175000         1955000
# 13051954  12021011102        White             1       875000         1095000
# 13051955  06037273800        White             1      1405000         1755000
# 13051956  12057005102        White             1      1445000         1925000
# 13051957  06037406300        Asian             1      1305000         2405000
# 13051958  06037534405        White             1       285000          505000
# 13051959  25019950400        White             1      2005000         6605000
# 13051960  36059415402        White             1      1725000         2155000
# 13051961  06037920035        White             1       615000          605000
# 13051962  06037273902        White             0       955000         1705000
# 13051963  06059075703        Asian             1      1005000         1345000
# 13051964  06059063500        Asian             1      3005000         6955000
# 13051965  06037273902        White             1       955000         1505000
# 13051966  34027044200        White             1      1875000         2885000
# 13051967  06037113233        White             1       615000          815000
# 13051968  06075012901        White             0      1235000         3135000
# 13051969  06037403324        Asian             1      1105000         1505000
# 13051970  06059042203        White             1       815000         1015000
# 13051971  06097151402        White             1       625000          905000
# 13051972  49043964305        White             1      2005000         3905000
# 13051973  36085018702        White             0       375000          545000
# 13051974  06059042203        White             0       765000         1015000
# 13051975  06083001402        White             1      3005000         7305000
# 13051976  15009030303        White             1      1615000         2695000
# 13051977  06097153102        White             1       575000          825000
# 13051978  36059405700        White             1       335000          655000
# 13051979  06083001208        White             0      1405000         2705000
# 13051980  06005000500        White             1       495000          615000
# 13051981  06037139801        White             1      2705000         4505000
# 13051982  53033031202        White             1       545000         2505000
# 13051983  04013613000        White             1       945000         1175000
# 13051984  08031003800        White             1       625000          725000
# 13051985  06073017110        White             1      2505000         3605000
# 13051986  06071000116        Asian             1       805000         1075000
# 13051987  48085030203        Asian             1       205000          275000
# 13051988  06037800325        White             1       825000         1105000
# 13051989  34001013101        White             1       545000         1105000
# 13051990  34029722100        White             0      1015000         1265000
# 13051991  33003956300        White             0      1085000         2405000
# 13051992  06037128601        White             1       385000          915000
# 13051993  06067009618        Joint             1       395000          415000
# 13051994  06071011206        White             0      3005000         4155000
# 13051995  06111005906        White             1       735000         1135000
# 13051996  34029722100        White             0      1015000         1265000
# 13051997  06037408703        Asian             1      1135000         1425000
# 13051998  12099003509        White             1       755000         1005000
# 13051999  42091205200        White             1       995000         2255000
# 13052000  04013216816        White             1       905000         1575000
# 13052001  06037274202        White             1      2325000         2905000
# 13052002  06017031700        Asian             1       595000         1085000
#
#           income debt_to_income_ratio  tract_minority_population_percent  \
# 13051943    1575                 <20%                              70.36
# 13051944    1587                 <20%                              89.29
# 13051945    1595             30%-<36%                              56.04
# 13051946    1597             20%-<30%                              30.34
# 13051947    1736                 <20%                              98.78
# 13051948    1739                 <20%                              98.78
# 13051949    1786                 <20%                              15.45
# 13051950    1736                 <20%                              98.78
# 13051951    1769             20%-<30%                              22.85
# 13051952    1795                 <20%                              38.34
# 13051953    1812                 <20%                              34.60
# 13051954    1829                 <20%                              18.59
# 13051955    1868             20%-<30%                              36.60
# 13051956    1903                 <20%                              22.11
# 13051957    1925                 <20%                              78.35
# 13051958    1736                 <20%                              98.78
# 13051959    1749                 <20%                              31.63
# 13051960    1786                 <20%                               8.15
# 13051961    1833                 <20%                              63.24
# 13051962    1880             20%-<30%                              21.77
# 13051963    1962             20%-<30%                              28.76
# 13051964    1805             20%-<30%                              16.43
# 13051965    1880             30%-<36%                              21.77
# 13051966    1914                 <20%                              14.15
# 13051967    1965             30%-<36%                              80.54
# 13051968    2209                 <20%                              22.38
# 13051969    2085                 <20%                              80.80
# 13051970    2171                 <20%                              17.91
# 13051971    2214             30%-<36%                              59.96
# 13051972    2288                 <20%                              21.08
# 13051973    2637                 <20%                              49.71
# 13051974    2808                 <20%                              17.91
# 13051975    2123                 <20%                               8.39
# 13051976    2174                 <20%                              28.81
# 13051977    2214             30%-<36%                              70.38
# 13051978    2411             30%-<36%                              29.33
# 13051979    2480                 <20%                              26.50
# 13051980    2565                 <20%                               6.20
# 13051981    2400             20%-<30%                              17.74
# 13051982    2855                 <20%                              27.02
# 13051983    3126                 <20%                              14.41
# 13051984    3391                 <20%                              13.20
# 13051985    4208                 <20%                              25.41
# 13051986    3405                 <20%                              68.21
# 13051987    3822                 <20%                              31.58
# 13051988    4188             20%-<30%                              14.56
# 13051989    4239                 <20%                               2.66
# 13051990    5433                 <20%                              18.32
# 13051991    6365                 <20%                               2.78
# 13051992    8031                 <20%                              62.63
# 13051993     166             30%-<36%                              65.91
# 13051994    3912                 <20%                              30.97
# 13051995    4327             20%-<30%                              22.43
# 13051996    5433                 <20%                              18.32
# 13051997    4712                 <20%                              87.78
# 13051998    5801                 <20%                               4.74
# 13051999    6361                 <20%                              10.47
# 13052000    6711                 <20%                              14.79
# 13052001    9154                 <20%                              15.56
# 13052002     240             30%-<36%                              23.70
#
#           tract_to_msa_income_percentage income_level dti_level
# 13051943                           131.0        upper      <20%
# 13051944                            91.0       middle      <20%
# 13051945                            38.0          low  30%-<36%
# 13051946                           162.0        upper  20%-<30%
# 13051947                            53.0     moderate      <20%
# 13051948                            53.0     moderate      <20%
# 13051949                           158.0        upper      <20%
# 13051950                            53.0     moderate      <20%
# 13051951                           184.0        upper  20%-<30%
# 13051952                           186.0        upper      <20%
# 13051953                           192.0        upper      <20%
# 13051954                            95.0       middle      <20%
# 13051955                           146.0        upper  20%-<30%
# 13051956                           265.0        upper      <20%
# 13051957                           158.0        upper      <20%
# 13051958                            53.0     moderate      <20%
# 13051959                           123.0        upper      <20%
# 13051960                           136.0        upper      <20%
# 13051961                            97.0       middle      <20%
# 13051962                           259.0        upper  20%-<30%
# 13051963                           178.0        upper  20%-<30%
# 13051964                           156.0        upper  20%-<30%
# 13051965                           259.0        upper  30%-<36%
# 13051966                           210.0        upper      <20%
# 13051967                            68.0     moderate  30%-<36%
# 13051968                           184.0        upper      <20%
# 13051969                           187.0        upper      <20%
# 13051970                           123.0        upper      <20%
# 13051971                            66.0     moderate  30%-<36%
# 13051972                           187.0        upper      <20%
# 13051973                           133.0        upper      <20%
# 13051974                           123.0        upper      <20%
# 13051975                           211.0        upper      <20%
# 13051976                           110.0       middle      <20%
# 13051977                            67.0     moderate  30%-<36%
# 13051978                           101.0       middle  30%-<36%
# 13051979                           170.0        upper      <20%
# 13051980                           117.0       middle      <20%
# 13051981                           273.0        upper  20%-<30%
# 13051982                            84.0       middle      <20%
# 13051983                           156.0        upper      <20%
# 13051984                           225.0        upper      <20%
# 13051985                           205.0        upper      <20%
# 13051986                           183.0        upper      <20%
# 13051987                           106.0       middle      <20%
# 13051988                           226.0        upper  20%-<30%
# 13051989                           163.0        upper      <20%
# 13051990                            96.0       middle      <20%
# 13051991                           129.0        upper      <20%
# 13051992                            65.0     moderate      <20%
# 13051993                            97.0       middle  30%-<36%
# 13051994                           117.0       middle      <20%
# 13051995                           157.0        upper  20%-<30%
# 13051996                            96.0       middle      <20%
# 13051997                           148.0        upper      <20%
# 13051998                           215.0        upper      <20%
# 13051999                           178.0        upper      <20%
# 13052000                           179.0        upper      <20%
# 13052001                           273.0        upper      <20%
# 13052002                           236.0        upper  30%-<36%

# %%
# drop original columns used to generate categorical data
hmda = hmda.drop(["debt_to_income_ratio", "tract_to_msa_income_percentage"], axis=1)

# %%
print(hmda.shape)
hmda.dropna(how="any").reset_index(drop=True)
print(hmda.shape)
# Out:
# (13052003, 9)
# (13052003, 9)

# %%
calculate_feature_statistics(hmda)
# Out:
#                                    num_zeros      prop_zeros  num_positives  \
# action_taken                       1874123.0  0.143588918881     11177880.0
# loan_amount                              0.0  0.000000000000     13052003.0
# property_value                           0.0  0.000000000000     13052003.0
# income                               54912.0  0.004207170348     12987832.0
# tract_minority_population_percent     5281.0  0.000404612227     13046722.0
#
#                                    prop_positives  num_negatives  \
# action_taken                       0.856411081119            0.0
# loan_amount                        1.000000000000            0.0
# property_value                     1.000000000000            0.0
# income                             0.995083436619         9259.0
# tract_minority_population_percent  0.999595387773            0.0
#
#                                    prop_negatives  num_missing  prop_missing  \
# action_taken                       0.000000000000          0.0           0.0
# loan_amount                        0.000000000000          0.0           0.0
# property_value                     0.000000000000          0.0           0.0
# income                             0.000709393033          0.0           0.0
# tract_minority_population_percent  0.000000000000          0.0           0.0
#
#                                    nunique_value    prop_nunique  min_value  \
# action_taken                                 2.0  0.000000153233        0.0
# loan_amount                                981.0  0.000075160878     5000.0
# property_value                            1440.0  0.000110327894     5000.0
# income                                    7476.0  0.000572785648  -126000.0
# tract_minority_population_percent        10591.0  0.000811446335        0.0
#
#                                       max_value  median_value
# action_taken                                1.0          1.00
# loan_amount                        1409715000.0     235000.00
# property_value                     1410005000.0     355000.00
# income                              381000000.0         94.00
# tract_minority_population_percent         100.0         22.51

# %% [markdown]
# #### Export data

# %%
hmda.to_csv("data/output/hmda_2021_CLEAN_"+str(today)+".csv", index=False, header=True)

# %%
hmda.to_parquet("data/output/hmda_2021_CLEAN_"+str(today), index=False)

# %% [markdown]
# ### Opt A: Group data by census tract ignore race

# %%
# hmda= pd.read_parquet("data/output/hmda_2021_CLEAN_2023-04-14", index=False)

# %%
hmda.columns
# Out:
# Index(['census_tract', 'derived_race', 'action_taken', 'loan_amount',
#        'property_value', 'income', 'tract_minority_population_percent',
#        'income_level', 'dti_level'],
#       dtype='object')

# %%
hmda.dtypes
# Out:
# census_tract                          object
# derived_race                          object
# action_taken                           int64
# loan_amount                            int64
# property_value                         int64
# income                                 int64
# tract_minority_population_percent    float64
# income_level                          object
# dti_level                             object
# dtype: object

# %%
# need to convert these categories to strings to get mode
hmda[["census_tract", "derived_race","income_level","dti_level"]] = hmda[["census_tract", "derived_race","income_level","dti_level"]].astype(str)

# %%
# Group by census tract
# Keep first value if multiple modes
mode = lambda x: pd.Series.mode(x)[0]

ct_group = hmda.groupby('census_tract', as_index=False).agg({
    'derived_race': mode,
    'action_taken': pd.Series.mean,
    "loan_amount": pd.Series.mean,
    "property_value": pd.Series.mean,
    "income": pd.Series.mean,
    'tract_minority_population_percent': pd.Series.mean,
    'income_level': mode,
    'dti_level': mode
})
print(ct_group.shape)
ct_group.tail()
# Out:
# (72684, 9)
#       census_tract               derived_race  action_taken  loan_amount  \
# 72679  78010971300  Black or African American           1.0     165000.0
# 72680  78010971500  Black or African American           1.0     175000.0
# 72681  78020950200                      White           0.0    1655000.0
# 72682  78030960100                      White           1.0     175000.0
# 72683  78030960400  Black or African American           0.5     365000.0
#
#        property_value  income  tract_minority_population_percent income_level  \
# 72679        225000.0    62.0                                0.0       middle
# 72680        215000.0   123.0                                0.0       middle
# 72681       2505000.0  1425.0                                0.0       middle
# 72682        215000.0   173.0                                0.0       middle
# 72683        745000.0    94.5                                0.0        upper
#
#       dti_level
# 72679  30%-<36%
# 72680  20%-<30%
# 72681      <20%
# 72682  20%-<30%
# 72683  30%-<36%

# %%
ct_group = ct_group.rename(columns={'action_taken':'approval'})

# %% [markdown]
# #### Export

# %%
ct_group[["census_tract", "derived_race", "income_level", "dti_level"]]= ct_group[["census_tract", "derived_race", "income_level", "dti_level"]].astype(str)

# %%
ct_group.to_csv("data/output/hmda_2021_ct_group_"+str(today)+".csv", index=False, header=True)
ct_group.to_parquet("data/output/hmda_2021_ct_group_"+str(today), index=False)

# %% [markdown]
# ### Opt B: Group by race

# %%
hmda["derived_race"].value_counts()
# Out:
# White                                        10515189
# Asian                                         1074853
# Black or African American                     1000392
# Joint                                          322215
# American Indian or Alaska Native                77992
# Native Hawaiian or Other Pacific Islander       34169
# 2 or more minority races                        27193
# Name: derived_race, dtype: int64

# %%
# Select race category and group by average action (percent of approval)

mode = lambda x: pd.Series.mode(x)[0]

black_group = hmda[hmda["derived_race"]=="Black or African American"].groupby('census_tract', as_index=False).agg({
    'action_taken': pd.Series.mean,
    "loan_amount": pd.Series.mean,
    "property_value": pd.Series.mean,
    "income": pd.Series.mean,
    'tract_minority_population_percent': pd.Series.mean,
    'income_level': mode,
    'dti_level': mode
})
print(black_group.shape)
black_group.tail(60)
# Out:
# (58363, 8)
#       census_tract    action_taken  loan_amount       property_value  \
# 58263  72127009400  0.333333333333      85000.0   91666.666666666672
# 58264  72127009601  1.000000000000      75000.0   95000.000000000000
# 58265  72127009602  1.000000000000      85000.0   95000.000000000000
# 58266  72127009603  0.000000000000     105000.0  135000.000000000000
# 58267  72127009614  1.000000000000     115000.0  125000.000000000000
# ...            ...             ...          ...                  ...
# 58358  78010970900  1.000000000000     155000.0  155000.000000000000
# 58359  78010971200  1.000000000000     185000.0  245000.000000000000
# 58360  78010971300  1.000000000000     165000.0  225000.000000000000
# 58361  78010971500  1.000000000000     175000.0  215000.000000000000
# 58362  78030960400  0.500000000000     365000.0  745000.000000000000
#
#                  income  tract_minority_population_percent income_level  \
# 58263   29.666666666667                              99.43       middle
# 58264   21.000000000000                              98.46        upper
# 58265   52.000000000000                             100.00        upper
# 58266   80.000000000000                              99.12        upper
# 58267   65.000000000000                              98.35        upper
# ...                 ...                                ...          ...
# 58358  102.000000000000                               0.00          low
# 58359  146.000000000000                               0.00       middle
# 58360   62.000000000000                               0.00       middle
# 58361  123.000000000000                               0.00       middle
# 58362   94.500000000000                               0.00        upper
#
#       dti_level
# 58263      >60%
# 58264  42%-<50%
# 58265  20%-<30%
# 58266      >60%
# 58267  42%-<50%
# ...         ...
# 58358  20%-<30%
# 58359      <20%
# 58360  30%-<36%
# 58361  20%-<30%
# 58362  30%-<36%
#
# [100 rows x 8 columns]

# %%
black_group = black_group.rename(columns={'action_taken':'approval_black'})

# %% [markdown]
# #### Export

# %%
black_group[["census_tract", "income_level", "dti_level"]]= black_group[["census_tract", "income_level", "dti_level"]].astype(str)

# %%
black_group.to_csv("data/output/hmda_2021_black_group"+str(today)+".csv", index=False, header=True)
black_group.to_parquet("data/output/hmda_2021_black_group"+str(today), index=False)

# %% [markdown]
# #### Next step: Run the Capstone_BV_ETL_SC_20230413
